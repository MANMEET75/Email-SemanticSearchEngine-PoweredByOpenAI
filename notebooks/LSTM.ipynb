# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import tensorflow as tf
tf.__version__
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Importing the dataset

# %%
dataset_train = pd.read_csv('emails.csv') 
dataset_train.duplicated().sum()
# Out:
# 0

# %%
def parse_raw_message(raw_message):
    lines = raw_message.split('\n')
    email = {}
    message = ''
    keys_to_extract = ['from', 'to']
    for line in lines:
        if ':' not in line:
            message += line.strip()
            email['body'] = message
        else:
            pairs = line.split(':')
            key = pairs[0].lower()
            val = pairs[1].strip()
            if key in keys_to_extract:
                email[key] = val
    return email

def parse_into_emails(messages):
    emails = [parse_raw_message(message) for message in messages]
    return {
        'body': map_to_list(emails, 'body'), 
        'to': map_to_list(emails, 'to'), 
        'from_': map_to_list(emails, 'from')
    }

def map_to_list(emails, key):
    results = []
    for email in emails:
        if key not in email:
            results.append('')
        else:
            results.append(email[key])
    return results

# %%
email_df = pd.DataFrame(parse_into_emails(dataset_train.message))
email_df.drop(email_df.query("body == '' | to == '' | from_ == ''").index, inplace=True)

# %%
email_df.head()
# Out:
#                                                 body                       to  \
# 0                               Here is our forecast     tim.belden@enron.com
# 1  Traveling to have a business meeting takes the...  john.lavorato@enron.com
# 2                     test successful.  way to go!!!   leah.arsdall@enron.com
# 3  Randy,Can you send me a schedule of the salary...    randall.gay@enron.com
# 5  Greg,How about either next Tuesday or Thursday...     greg.piper@enron.com
#
#                      from_
# 0  phillip.allen@enron.com
# 1  phillip.allen@enron.com
# 2  phillip.allen@enron.com
# 3  phillip.allen@enron.com
# 5  phillip.allen@enron.com

# %% [markdown]
# ## Getting the shape of the dataset

# %%
email_df.shape
# Out:
# (491067, 3)

# %% [markdown]
# ## Preprocessing the dataset

# %%
def preprocess_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    '''
    Preprocess a string.
    :parameter
        :param text: string - name of column containing text
        :param lst_stopwords: list - list of stopwords to remove
        :param flg_stemm: bool - whether stemming is to be applied
        :param flg_lemm: bool - whether lemmitisation is to be applied
    :return
        cleaned text
    '''

    ## clean (convert to lowercase and remove punctuations and characters and then strip)
    text = re.sub(r'[^\w\s]', '', str(text).lower().strip())
            
    ## Tokenize (convert from string to list)
    lst_text = text.split()
    
    ## remove Stopwords
    if lst_stopwords is not None:
        lst_text = [word for word in lst_text if word not in lst_stopwords]
                
    ## Stemming (remove -ing, -ly, ...)
    if flg_stemm == True:
        ps = nltk.stem.porter.PorterStemmer()
        lst_text = [ps.stem(word) for word in lst_text]
                
    ## Lemmatisation (convert the word into root word)
    if flg_lemm == True:
        lem = nltk.stem.wordnet.WordNetLemmatizer()
        lst_text = [lem.lemmatize(word) for word in lst_text]
            
    ## back to string from list
    text = " ".join(lst_text)
    return text

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\revoquant\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
lst_stopwords = nltk.corpus.stopwords.words("english")

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\revoquant\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
email_df["body_clean"] = email_df["body"].apply(lambda x: preprocess_text(x, flg_stemm=False, flg_lemm=True, lst_stopwords=lst_stopwords))
email_df.head()
# Out:
#                                                 body                       to  \
# 0                               Here is our forecast     tim.belden@enron.com
# 1  Traveling to have a business meeting takes the...  john.lavorato@enron.com
# 2                     test successful.  way to go!!!   leah.arsdall@enron.com
# 3  Randy,Can you send me a schedule of the salary...    randall.gay@enron.com
# 5  Greg,How about either next Tuesday or Thursday...     greg.piper@enron.com
#
#                      from_                                         body_clean
# 0  phillip.allen@enron.com                                           forecast
# 1  phillip.allen@enron.com  traveling business meeting take fun trip espec...
# 2  phillip.allen@enron.com                             test successful way go
# 3  phillip.allen@enron.com  randycan send schedule salary level everyone t...
# 5  phillip.allen@enron.com        greghow either next tuesday thursdayphillip

# %%
email_df.groupby('to').describe()
# Out:
#                                                     body         \
#                                                    count unique
# to
# "        -         *Chris.Germany@enron.com" <C...     4      2
# "        -         *Destephanis, Kara" <kdestep...     3      1
# "        -         *Kinney, Doug" <dkinney@colu...     6      2
# "        -         *Koch, Kent" <kkoch@nisource...     4      1
# "        -         *Scott.Goodell@enron.com" <S...     7      2
# ...                                                  ...    ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...     4      3
# zwharton@dawray.com                                   43     28
# zwharton@dawray.com, w.dangerfield@deaus.com, c...     1      1
# ~*Everyone At San Ramon/Western Region/The Bent...     2      1
# ~Twink~ <twink@fuse.net>                               1      1
#
#                                                                                                        \
#                                                                                                   top
# to
# "        -         *Chris.Germany@enron.com" <C...  DoneChris,Please fax the support sent to you o...
# "        -         *Destephanis, Kara" <kdestep...  For 1/19th we have sold the extra capacity to ...
# "        -         *Kinney, Doug" <dkinney@colu...  They want firm primary.---------------------- ...
# "        -         *Koch, Kent" <kkoch@nisource...  AM ---------------------------*Millar, Debra" ...
# "        -         *Scott.Goodell@enron.com" <S...  I will assume you de' man on this one.Chris Ge...
# ...                                                                                               ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...  dahncke.beth@enron.com, lyons.bill@enron.com, ...
# zwharton@dawray.com                                 Credit cards that is! - I just requested anoth...
# zwharton@dawray.com, w.dangerfield@deaus.com, c...  chuckrutt@hotmail.com, dschlich@csc.com, dgree...
# ~*Everyone At San Ramon/Western Region/The Bent...  jeff.dasovich@enron.com, ryan.deane@enron.com,...
# ~Twink~ <twink@fuse.net>                            holden.salisbury@enron.com, tom.alonso@enron.c...
#
#                                                         from_         \
#                                                    freq count unique
# to
# "        -         *Chris.Germany@enron.com" <C...    2     4      1
# "        -         *Destephanis, Kara" <kdestep...    3     3      1
# "        -         *Kinney, Doug" <dkinney@colu...    3     6      2
# "        -         *Koch, Kent" <kkoch@nisource...    4     4      1
# "        -         *Scott.Goodell@enron.com" <S...    4     7      2
# ...                                                 ...   ...    ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...    2     4      1
# zwharton@dawray.com                                   4    43      5
# zwharton@dawray.com, w.dangerfield@deaus.com, c...    1     1      1
# ~*Everyone At San Ramon/Western Region/The Bent...    2     2      1
# ~Twink~ <twink@fuse.net>                              1     1      1
#
#                                                                                                        \
#                                                                                                   top
# to
# "        -         *Chris.Germany@enron.com" <C...                            chris.germany@enron.com
# "        -         *Destephanis, Kara" <kdestep...                            joann.collins@enron.com
# "        -         *Kinney, Doug" <dkinney@colu...                          clarissa.garcia@enron.com
# "        -         *Koch, Kent" <kkoch@nisource...                            judy.townsend@enron.com
# "        -         *Scott.Goodell@enron.com" <S...                            chris.germany@enron.com
# ...                                                                                               ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...                               ava.garcia@enron.com
# zwharton@dawray.com                                                           martin.cuilla@enron.com
# zwharton@dawray.com, w.dangerfield@deaus.com, c...                                lfrank@vignette.com
# ~*Everyone At San Ramon/Western Region/The Bent...  Jeannine Huda/Western Region/The Bentley Compa...
# ~Twink~ <twink@fuse.net>                                                             <twink@fuse.net>
#
#                                                         body_clean         \
#                                                    freq      count unique
# to
# "        -         *Chris.Germany@enron.com" <C...    4          4      2
# "        -         *Destephanis, Kara" <kdestep...    3          3      1
# "        -         *Kinney, Doug" <dkinney@colu...    3          6      2
# "        -         *Koch, Kent" <kkoch@nisource...    4          4      1
# "        -         *Scott.Goodell@enron.com" <S...    4          7      2
# ...                                                 ...        ...    ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...    4          4      3
# zwharton@dawray.com                                  19         43     28
# zwharton@dawray.com, w.dangerfield@deaus.com, c...    1          1      1
# ~*Everyone At San Ramon/Western Region/The Bent...    2          2      1
# ~Twink~ <twink@fuse.net>                              1          1      1
#
#                                                                                                        \
#                                                                                                   top
# to
# "        -         *Chris.Germany@enron.com" <C...  donechrisplease fax support sent contact cindy...
# "        -         *Destephanis, Kara" <kdestep...  119th sold extra capacity amoco5000 bgecitygat...
# "        -         *Kinney, Doug" <dkinney@colu...  want firm primary forwarded clarissa garciahou...
# "        -         *Koch, Kent" <kkoch@nisource...  millar debra dmillarnisourcecom burke lynnlbur...
# "        -         *Scott.Goodell@enron.com" <S...  assume de man onechris germanyhouectectagl sen...
# ...                                                                                               ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...  dahnckebethenroncom lyonsbillenroncom matticeb...
# zwharton@dawray.com                                 credit card requested another 50 macys gc isst...
# zwharton@dawray.com, w.dangerfield@deaus.com, c...  chuckrutthotmailcom dschlichcsccom dgreenclaus...
# ~*Everyone At San Ramon/Western Region/The Bent...  jeffdasovichenroncom ryandeaneenroncom lairddy...
# ~Twink~ <twink@fuse.net>                            holdensalisburyenroncom tomalonsoenroncommarkf...
#
#
#                                                    freq
# to
# "        -         *Chris.Germany@enron.com" <C...    2
# "        -         *Destephanis, Kara" <kdestep...    3
# "        -         *Kinney, Doug" <dkinney@colu...    3
# "        -         *Koch, Kent" <kkoch@nisource...    4
# "        -         *Scott.Goodell@enron.com" <S...    4
# ...                                                 ...
# zuroff.adele@enron.com, gold.amy@enron.com, wel...    2
# zwharton@dawray.com                                   4
# zwharton@dawray.com, w.dangerfield@deaus.com, c...    1
# ~*Everyone At San Ramon/Western Region/The Bent...    2
# ~Twink~ <twink@fuse.net>                              1
#
# [65739 rows x 12 columns]

# %%
email_df.groupby('from_').describe()
# Out:
#                                                     body         \
#                                                    count unique
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>             3      1
# "" <subs@btu.net>@ENRON                                4      4
# ""m y-" <enronsato@hotmail.com>@ENRON                  6      1
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto        1      1
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...     6      3
# ...                                                  ...    ...
# zufferli@enron.com                                     2      2
# zulie.flores@enron.com                                 6      3
# zvo2z17d0@untappedmarkets.com                          1      1
# zwharton@dawray.com                                    2      2
# zzmacmac@aol.com                                       2      2
#
#                                                                                                        \
#                                                                                                   top
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>          AM ---------------------------today volBill,Th...
# "" <subs@btu.net>@ENRON                             -----Original Message-----Attached is the late...
# ""m y-" <enronsato@hotmail.com>@ENRON               Jeff wants to know what you think about this. ...
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto     How about 2002's? I was just thinking there wo...
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...  and EPErqb@tozzini.com.brrqb@tozzini.com.brAna...
# ...                                                                                               ...
# zufferli@enron.com                                  I think I've already responded, but, we are OK...
# zulie.flores@enron.com                              kevin.howard@enron.com, harold.inman@enron.com...
# zvo2z17d0@untappedmarkets.com                       Would YOU  like to learn more about a company ...
# zwharton@dawray.com                                 Hey honey, will you please follow up with Tony...
# zzmacmac@aol.com                                    Thanks for sending Dr Lu -- Zimin did a great ...
#
#                                                            to         \
#                                                    freq count unique
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>            3     3      1
# "" <subs@btu.net>@ENRON                               1     4      2
# ""m y-" <enronsato@hotmail.com>@ENRON                 6     6      1
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto       1     1      1
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...    2     6      1
# ...                                                 ...   ...    ...
# zufferli@enron.com                                    1     2      1
# zulie.flores@enron.com                                3     6      2
# zvo2z17d0@untappedmarkets.com                         1     1      1
# zwharton@dawray.com                                   1     2      1
# zzmacmac@aol.com                                      1     2      1
#
#                                                                                                        \
#                                                                                                   top
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>                                 Billyoung3@aol.com @ ENRON
# "" <subs@btu.net>@ENRON                                                      Btus Weekly Power Report
# ""m y-" <enronsato@hotmail.com>@ENRON                                                  Skilling, Jeff
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto                                        Dorland, Chris
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...  <john.schwartzenburg@enron.com>, <randy.pais@e...
# ...                                                                                               ...
# zufferli@enron.com                                                            john.lavorato@enron.com
# zulie.flores@enron.com                              marla.barnard@enron.com, cynthia.barrow@enron....
# zvo2z17d0@untappedmarkets.com                                        undisclosed-recipients@enron.com
# zwharton@dawray.com                                                                 mcuilla@enron.com
# zzmacmac@aol.com                                                                 j.kaminski@enron.com
#
#                                                         body_clean         \
#                                                    freq      count unique
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>            3          3      1
# "" <subs@btu.net>@ENRON                               2          4      4
# ""m y-" <enronsato@hotmail.com>@ENRON                 6          6      1
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto       1          1      1
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...    6          6      3
# ...                                                 ...        ...    ...
# zufferli@enron.com                                    2          2      2
# zulie.flores@enron.com                                3          6      3
# zvo2z17d0@untappedmarkets.com                         1          1      1
# zwharton@dawray.com                                   2          2      2
# zzmacmac@aol.com                                      2          2      2
#
#                                                                                                        \
#                                                                                                   top
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>          today volbillthe vr 375 a1d gas well currently...
# "" <subs@btu.net>@ENRON                             original messageattached latest issue btu week...
# ""m y-" <enronsato@hotmail.com>@ENRON               jeff want know think srsoriginal messageonenro...
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto     2002s thinking would incentive 2001schrisorigi...
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...  eperqbtozzinicombrrqbtozzinicombrana paula tha...
# ...                                                                                               ...
# zufferli@enron.com                                       think ive already responded ok power trading
# zulie.flores@enron.com                              kevinhowardenroncom haroldinmanenroncomvinceka...
# zvo2z17d0@untappedmarkets.com                       would like learn company product virtually unt...
# zwharton@dawray.com                                 hey honey please follow tony 7132995034 aboutw...
# zzmacmac@aol.com                                    thanks sending dr lu zimin great job immeasure...
#
#
#                                                    freq
# from_
# " Walter McDougle" <wmcdougle@spinexp.com>            3
# "" <subs@btu.net>@ENRON                               1
# ""m y-" <enronsato@hotmail.com>@ENRON                 6
# "3Toyota" <3toyota@cadvision.com>@ENRON [mailto       1
# "=?ISO-8859-1?Q?APG=20-=20Ana=20Paula=20Gon=E7a...    2
# ...                                                 ...
# zufferli@enron.com                                    1
# zulie.flores@enron.com                                3
# zvo2z17d0@untappedmarkets.com                         1
# zwharton@dawray.com                                   1
# zzmacmac@aol.com                                      1
#
# [37179 rows x 12 columns]

# %%
email_df.groupby('body_clean').describe()
# Out:
#                                                     body         \
#                                                    count unique
# body_clean
#                                                      450    105
# 0 011038original messagecommissioners attached ...     1      1
# 0 011038original messagecxwcpuccagov gfbcpuccag...     2      1
# 0 5 percent would similar bod enron turning pro...     1      1
# 0 bid christie g anderson akers2 bid kevin john...     4      1
# ...                                                  ...    ...
# zuliefloresenroncomhere frank prepared sent lay...     1      1
# zuliei shall take bus tuesday morning adet brea...     1      1
# zulievince kaminski                                    1      1
# zwe making list directory need moved netco dire...     1      1
# zydeco chineseoriginal messagekevinare yall rea...     1      1
#
#                                                                                                        \
#                                                                                                   top
# body_clean
#                                                                                   *~*~*~*~*~*~*~*~*~*
# 0 011038original messagecommissioners attached ...  0\t0-11-038-----Original Message-----Commissio...
# 0 011038original messagecxwcpuccagov gfbcpuccag...  0\t0-11-038-----Original Message-----'CXW@cpuc...
# 0 5 percent would similar bod enron turning pro...  0 to 5 percent.  It would be similar to having...
# 0 bid christie g anderson akers2 bid kevin john...  $0 bids for S Christie, G Anderson, and D Aker...
# ...                                                                                               ...
# zuliefloresenroncomhere frank prepared sent lay...  zulie.flores@enron.comHere is what Frank prepa...
# zuliei shall take bus tuesday morning adet brea...  Zulie,I shall take the bus Tuesday morning to ...
# zulievince kaminski                                                              Zulie,Vince Kaminski
# zwe making list directory need moved netco dire...  Z,We have been making lists of the directories...
# zydeco chineseoriginal messagekevinare yall rea...  What is Zydeco?   No to Chinese.-----Original ...
#
#                                                            to         \
#                                                    freq count unique
# body_clean
#                                                     121   450    210
# 0 011038original messagecommissioners attached ...    1     1      1
# 0 011038original messagecxwcpuccagov gfbcpuccag...    2     2      1
# 0 5 percent would similar bod enron turning pro...    1     1      1
# 0 bid christie g anderson akers2 bid kevin john...    4     4      1
# ...                                                 ...   ...    ...
# zuliefloresenroncomhere frank prepared sent lay...    1     1      1
# zuliei shall take bus tuesday morning adet brea...    1     1      1
# zulievince kaminski                                   1     1      1
# zwe making list directory need moved netco dire...    1     1      1
# zydeco chineseoriginal messagekevinare yall rea...    1     1      1
#
#                                                                                                        \
#                                                                                                   top
# body_clean
#                                                                                    w..white@enron.com
# 0 011038original messagecommissioners attached ...  'LYN@cpuc.ca.gov'; 'RB1@cpuc.ca.gov'; 'HMD@cpu...
# 0 011038original messagecxwcpuccagov gfbcpuccag...  'LYN@cpuc.ca.gov'; 'RB1@cpuc.ca.gov'; 'HMD@cpu...
# 0 5 percent would similar bod enron turning pro...                           louise.kitchen@enron.com
# 0 bid christie g anderson akers2 bid kevin john...                            patrick.ryder@enron.com
# ...                                                                                               ...
# zuliefloresenroncomhere frank prepared sent lay...          "'etilney@enron.com'" <etilney@enron.com>
# zuliei shall take bus tuesday morning adet brea...                             zulie.flores@enron.com
# zulievince kaminski                                                            zulie.flores@enron.com
# zwe making list directory need moved netco dire...                              zhiyong.wei@enron.com
# zydeco chineseoriginal messagekevinare yall rea...                                   Presto, Kevin M.
#
#                                                         from_         \
#                                                    freq count unique
# body_clean
#                                                      18   450    147
# 0 011038original messagecommissioners attached ...    1     1      1
# 0 011038original messagecxwcpuccagov gfbcpuccag...    2     2      1
# 0 5 percent would similar bod enron turning pro...    1     1      1
# 0 bid christie g anderson akers2 bid kevin john...    4     4      1
# ...                                                 ...   ...    ...
# zuliefloresenroncomhere frank prepared sent lay...    1     1      1
# zuliei shall take bus tuesday morning adet brea...    1     1      1
# zulievince kaminski                                   1     1      1
# zwe making list directory need moved netco dire...    1     1      1
# zydeco chineseoriginal messagekevinare yall rea...    1     1      1
#
#                                                                                                  \
#                                                                                             top
# body_clean
#                                                                       matthew.lenhart@enron.com
# 0 011038original messagecommissioners attached ...  JBennett <JBennett@GMSSR.com>@ENRON [mailto
# 0 011038original messagecxwcpuccagov gfbcpuccag...          JBennett <JBennett@GMSSR.com>@ENRON
# 0 5 percent would similar bod enron turning pro...                       charles.ward@enron.com
# 0 bid christie g anderson akers2 bid kevin john...                          eric.bass@enron.com
# ...                                                                                         ...
# zuliefloresenroncomhere frank prepared sent lay...                   elizabeth.tilney@enron.com
# zuliei shall take bus tuesday morning adet brea...                         j.kaminski@enron.com
# zulievince kaminski                                                        j.kaminski@enron.com
# zwe making list directory need moved netco dire...                         kam.keiser@enron.com
# zydeco chineseoriginal messagekevinare yall rea...                            Black, Tamara Jae
#
#
#                                                    freq
# body_clean
#                                                      51
# 0 011038original messagecommissioners attached ...    1
# 0 011038original messagecxwcpuccagov gfbcpuccag...    2
# 0 5 percent would similar bod enron turning pro...    1
# 0 bid christie g anderson akers2 bid kevin john...    4
# ...                                                 ...
# zuliefloresenroncomhere frank prepared sent lay...    1
# zuliei shall take bus tuesday morning adet brea...    1
# zulievince kaminski                                   1
# zwe making list directory need moved netco dire...    1
# zydeco chineseoriginal messagekevinare yall rea...    1
#
# [227343 rows x 12 columns]

# %% [markdown]
# ## Creating the features which indicates that the email is fraud or there is fraud related message in that particular email1

# %%
fraud_related_words = ['fraud', 'scam', 'phishing', 'malware', 'deception', 'hoax']  # Add more fraud-related words if needed

email_df['fraud'] = email_df['body_clean'].apply(lambda x: 1 if any(word in x.lower() for word in fraud_related_words) else 0)
email_df.head()
# Out:
#                                                 body                       to  \
# 0                               Here is our forecast     tim.belden@enron.com
# 1  Traveling to have a business meeting takes the...  john.lavorato@enron.com
# 2                     test successful.  way to go!!!   leah.arsdall@enron.com
# 3  Randy,Can you send me a schedule of the salary...    randall.gay@enron.com
# 5  Greg,How about either next Tuesday or Thursday...     greg.piper@enron.com
#
#                      from_                                         body_clean  \
# 0  phillip.allen@enron.com                                           forecast
# 1  phillip.allen@enron.com  traveling business meeting take fun trip espec...
# 2  phillip.allen@enron.com                             test successful way go
# 3  phillip.allen@enron.com  randycan send schedule salary level everyone t...
# 5  phillip.allen@enron.com        greghow either next tuesday thursdayphillip
#
#    fraud
# 0      0
# 1      0
# 2      0
# 3      0
# 5      0

# %%
email_df.groupby('fraud').describe()
# Out:
#          body                                                             \
#         count  unique                                                top
# fraud
# 0      488345  227154  geir.solberg@enron.com, john.anderson@enron.co...
# 1        2722    1336  BUSINESS HIGHLIGHTSTRANSACTION DEVELOPMENTTran...
#
#                  to                                                            \
#        freq   count unique                                                top
# fraud
# 0      2135  488345  65404                               pete.davis@enron.com
# 1        35    2722    699  David_Aamodt@pgn.com, dapnucc@teleport.com, di...
#
#               from_                                   body_clean          \
#        freq   count unique                 top   freq      count  unique
# fraud
# 0      9097  488345  36978  kay.mann@enron.com  12312     488345  226007
# 1        59    2722    616      Lebrocq, Wendi     58       2722    1336
#
#
#                                                      top  freq
# fraud
# 0      geirsolbergenroncom johnandersonenroncommarkgu...  2135
# 1      business highlightstransaction developmenttran...    35

# %%
observations_class_0 = email_df[email_df['fraud'] == 1]

# %%
observations_class_0
# Out:
#                                                      body  \
# 1332    TheStreet.com and Privista are pleased to pres...
# 3054    Premonition?=20=09=09=09British Trader Sentenc...
# 3326    The problem if we limit the size on options to...
# 3947    paul.mead@enron.com, david.gallagher@enron.com...
# 3949    Premonition?=20=09=09=09British Trader Sentenc...
# ...                                                   ...
# 515584  d..gros@enron.com, kerry.roper@enron.combrenda...
# 515586  d..gros@enron.com, steve.hotte@enron.com, exec...
# 515587  d..gros@enron.com, steve.hotte@enron.com, exec...
# 515826  w..brown@enron.com, john.cummings@enron.com, h...
# 515970  w..brown@enron.com, john.cummings@enron.com, h...
#
#                                                        to  \
# 1332                                members@realmoney.com
# 3054                              John Arnold/HOU/ECT@ECT
# 3326                                andy.zipper@enron.com
# 3947    richard.lewis@enron.com, john.lavorato@enron.c...
# 3949                              John Arnold/HOU/ECT@ECT
# ...                                                   ...
# 515584  rex.shelby@enron.com, andy.zipper@enron.com, s...
# 515586  jeff.bartlett@enron.com, sally.beck@enron.com,...
# 515587  jeff.bartlett@enron.com, sally.beck@enron.com,...
# 515826  jeff.bartlett@enron.com, sally.beck@enron.com,...
# 515970  jeff.bartlett@enron.com, sally.beck@enron.com,...
#
#                            from_  \
# 1332       members@realmoney.com
# 3054       john.arnold@enron.com
# 3326       john.arnold@enron.com
# 3947        bob.shults@enron.com
# 3949       john.arnold@enron.com
# ...                          ...
# 515584    tina.spiller@enron.com
# 515586    tina.spiller@enron.com
# 515587    tina.spiller@enron.com
# 515826  peggy.mccurley@enron.com
# 515970  peggy.mccurley@enron.com
#
#                                                body_clean  fraud
# 1332    thestreetcom privista pleased present withcred...      1
# 3054    premonition20090909british trader sentenced pr...      1
# 3326    problem limit size option size offered onthe s...      1
# 3947    paulmeadenroncom davidgallagherenroncomgregorb...      1
# 3949    premonition20090909british trader sentenced pr...      1
# ...                                                   ...    ...
# 515584  dgrosenroncom kerryroperenroncombrendaflorescu...      1
# 515586  dgrosenroncom stevehotteenroncom execjonesenro...      1
# 515587  dgrosenroncom stevehotteenroncom execjonesenro...      1
# 515826  wbrownenroncom johncummingsenroncom hdouglasen...      1
# 515970  wbrownenroncom johncummingsenroncom hdouglasen...      1
#
# [2722 rows x 5 columns]

# %% [markdown]
# ## Taking care of missing values if present over here

# %%
email_df.isnull().sum()
# Out:
# body          0
# to            0
# from_         0
# body_clean    0
# fraud         0
# dtype: int64

# %% [markdown]
# No missing values are there inside the dataset

# %%
X=email_df.drop('fraud',axis=1)
y=email_df['fraud']

# %%
X.head(2)
# Out:
#                                                 body                       to  \
# 0                               Here is our forecast     tim.belden@enron.com
# 1  Traveling to have a business meeting takes the...  john.lavorato@enron.com
#
#                      from_                                         body_clean
# 0  phillip.allen@enron.com                                           forecast
# 1  phillip.allen@enron.com  traveling business meeting take fun trip espec...

# %%
X.shape
# Out:
# (491067, 4)

# %%
y.head(2)
# Out:
# 0    0
# 1    0
# Name: fraud, dtype: int64

# %%
y.shape
# Out:
# (491067,)

# %% [markdown]
# ## Splitting the dataset into training set and testing set over here

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0,stratify=email_df['fraud'])

# %% [markdown]
# ## Dealing with imbalanced dataset

# %%
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler 

# Specify the sampling_strategy as a float or dictionary
# For example, if you want to under-sample the majority class to have 80% of the minority class:
ns = RandomUnderSampler(sampling_strategy=0.8)

# Assuming you have already defined X_train and y_train
X_train_ns, y_train_ns = ns.fit_resample(X_train, y_train)

print("The number of classes before fit: {}".format(Counter(y_train)))
print("The number of classes after fit {}".format(Counter(y_train_ns)))
# Out:
# The number of classes before fit: Counter({0: 366259, 1: 2041})
# The number of classes after fit Counter({0: 2551, 1: 2041})

# %% [markdown]
# ## Cleaning the text

# %%
messages=X.copy()

# %%
messages['body'][1]
# Out:
# "Traveling to have a business meeting takes the fun out of the trip.  Especially if you have to prepare a presentation.  I would suggest holding the business plan meetings here then take a trip without any formal business meetings.  I would even try and get some honest opinions on whether a trip is even desired or necessary.As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.  Too often the presenter speaks and the others are quiet just waiting for their turn.   The meetings might be better if held in a round table discussion format.My suggestion for where to go is Austin.  Play golf and rent a ski boat and jet ski's.  Flying somewhere takes too much time."

# %%
messages.reset_index(inplace=True)

# %%
messages
# Out:
#          index                                               body  \
# 0            0                               Here is our forecast
# 1            1  Traveling to have a business meeting takes the...
# 2            2                     test successful.  way to go!!!
# 3            3  Randy,Can you send me a schedule of the salary...
# 4            5  Greg,How about either next Tuesday or Thursday...
# ...        ...                                                ...
# 491062  517396  This is a trade with OIL-SPEC-HEDGE-NG (John L...
# 491063  517397  Some of my position is with the Alberta Term b...
# 491064  517398  2-----Original Message-----Morning John,I'm st...
# 491065  517399  Analyst\t\t\t\t\tRankStephane Brodeur\t\t\t1Ch...
# 491066  517400  i think the YMCA has a class that is for peopl...
#
#                              to                             from_  \
# 0          tim.belden@enron.com           phillip.allen@enron.com
# 1       john.lavorato@enron.com           phillip.allen@enron.com
# 2        leah.arsdall@enron.com           phillip.allen@enron.com
# 3         randall.gay@enron.com           phillip.allen@enron.com
# 4          greg.piper@enron.com           phillip.allen@enron.com
# ...                         ...                               ...
# 491062     kori.loibl@enron.com           john.zufferli@enron.com
# 491063  john.lavorato@enron.com           john.zufferli@enron.com
# 491064           Zufferli, John                      Doucet, Dawn
# 491065   jeanie.slone@enron.com           john.zufferli@enron.com
# 491066           Zufferli, John  Livia_Zufferli@Monitor.com@ENRON
#
#                                                body_clean
# 0                                                forecast
# 1       traveling business meeting take fun trip espec...
# 2                                  test successful way go
# 3       randycan send schedule salary level everyone t...
# 4             greghow either next tuesday thursdayphillip
# ...                                                   ...
# 491062  trade oilspechedgeng john lavoratos book john ...
# 491063  position alberta term book send position direc...
# 491064  2original messagemorning johnim still working ...
# 491065  analyst rankstephane brodeur 1chad clark 1ian ...
# 491066  think ymca class people recovering heartattack...
#
# [491067 rows x 5 columns]
